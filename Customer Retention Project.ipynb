# %%
import pandas as pd
df = pd.read_excel (r'D:\For Internship\Customer Retention data1.xlsx')

# %%
df
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
df=df.iloc[:,0:47]
df
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df.isnull().sum()
# Out:
# 1Gender of respondent                                                                                                                                                                                                  0
# 2 How old are you?                                                                                                                                                                                                     0
# 3 Which city do you shop online from?                                                                                                                                                                                  0
# 4 What is the Pin Code of where you shop online from?                                                                                                                                                                  0
# ...

# %% [markdown]
# we see that there is no null value in the dataset

# %% [markdown]
# # EDA Part Of The Dataset

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(10,7))
plt.title(df.columns[0],fontsize=30,color='Blue')
sns.countplot(df[df.columns[0]])
# Out:
# <AxesSubplot:title={'center':'1Gender of respondent'}, xlabel='1Gender of respondent', ylabel='count'>

# %% [markdown]
# We can see that there are more female customers than male customers

# %%
n=1
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=30,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'2 How old are you? '}, xlabel='2 How old are you? ', ylabel='count'>

# %% [markdown]
# We see that the number of customers between the ages of 21 and 40 is the highest.

# %%
n=2
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=30,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'3 Which city do you shop online from?'}, xlabel='3 Which city do you shop online from?', ylabel='count'>

# %% [markdown]
# we see from the above graph most of the people shop online from Delhi,Greater Noida,Noida,Bangalore,Karnal

# %%
n=3
plt.figure(figsize=(30,7))
plt.title(df.columns[n],fontsize=30,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'4 What is the Pin Code of where you shop online from?'}, xlabel='4 What is the Pin Code of where you shop online from?', ylabel='count'>

# %% [markdown]
# we see from the above graph maximum used pin code for online shoping.

# %%
n=4
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=30,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'5 Since How Long You are Shopping Online ?'}, xlabel='5 Since How Long You are Shopping Online ?', ylabel='count'>

# %% [markdown]
# We can see that most of the customers have been shopping for more than four years

# %%
n=5
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=30,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'6 How many times you have made an online purchase in the past 1 year?'}, xlabel='6 How many times you have made an online purchase in the past 1 year?', ylabel='count'>

# %% [markdown]
# we can see that most of the customers have made less than 10 times online purchase in the past 1 year But the number of customers who have shopped more than 30 times is not less

# %%
n=6
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=30,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'7 How do you access the internet while shopping on-line?'}, xlabel='7 How do you access the internet while shopping on-line?', ylabel='count'>

# %% [markdown]
# we can see that Most of the customers use mobile internet for online shopping

# %%
n=7
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=30,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'8 Which device do you use to access the online shopping?'}, xlabel='8 Which device do you use to access the online shopping?', ylabel='count'>

# %% [markdown]
# we see from the above plot Most of the customers use mobiles or laptop for online shopping and use tablets and desktop very rarely.

# %%
n=8
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=30,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        '}, xlabel='9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ', ylabel='count'>

# %% [markdown]
# The screen size of most customers' mobiles is 5.5 inches or others

# %%
n=9
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=30,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'10 What is the operating system (OS) of your device?\t\t\t\t                                          '}, xlabel='10 What is the operating system (OS) of your device?\t\t\t\t                                          ', ylabel='count'>

# %% [markdown]
# Most of the customer's devices have Windows or Android operating system

# %%
n=10
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'11 What browser do you run on your device to access the website?\t\t\t                                                          '}, xlabel='11 What browser do you run on your device to access the website?\t\t\t                                                          ', ylabel='count'>

# %% [markdown]
# we see that The browser that most customers use for online shopping is Chrome and Others Browsers use rearly.

# %%
n=11
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '}, xlabel='12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ', ylabel='count'>

# %% [markdown]
# This is the first time a customer uses it to reach their favorite online store is Search engine.

# %%
n=12
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   '}, xlabel='13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ', ylabel='count'>

# %% [markdown]
# After First Visit, most Customer Reaches Online Retail Stores Through Search Engines,via application or Direct URL

# %%
n=13
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '}, xlabel='14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ', ylabel='count'>

# %%
n=14
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '}, xlabel='15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ', ylabel='count'>

# %%
n=15
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   '}, xlabel='16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ', ylabel='count'>

# %%
n=16
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       '}, xlabel='17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ', ylabel='count'>

# %%
n=17
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'18 The content on the website must be easy to read and understand'}, xlabel='18 The content on the website must be easy to read and understand', ylabel='count'>

# %%
n=18
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'19 Information on similar product to the one highlighted  is important for product comparison'}, xlabel='19 Information on similar product to the one highlighted  is important for product comparison', ylabel='count'>

# %%
n=19
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'20 Complete information on listed seller and product being offered is important for purchase decision.'}, xlabel='20 Complete information on listed seller and product being offered is important for purchase decision.', ylabel='count'>

# %%
n=20
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'21 All relevant information on listed products must be stated clearly'}, xlabel='21 All relevant information on listed products must be stated clearly', ylabel='count'>

# %%
n=21
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'22 Ease of navigation in website'}, xlabel='22 Ease of navigation in website', ylabel='count'>

# %%
n=22
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'23 Loading and processing speed'}, xlabel='23 Loading and processing speed', ylabel='count'>

# %%
n=23
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'24 User friendly Interface of the website'}, xlabel='24 User friendly Interface of the website', ylabel='count'>

# %%
n=24
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'25 Convenient Payment methods'}, xlabel='25 Convenient Payment methods', ylabel='count'>

# %%
n=25
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'}, xlabel='26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time', ylabel='count'>

# %%
n=26
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'27 Empathy (readiness to assist with queries) towards the customers'}, xlabel='27 Empathy (readiness to assist with queries) towards the customers', ylabel='count'>

# %%
n=27
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'28 Being able to guarantee the privacy of the customer'}, xlabel='28 Being able to guarantee the privacy of the customer', ylabel='count'>

# %%
n=28
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'}, xlabel='29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)', ylabel='count'>

# %%
n=29
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'30 Online shopping gives monetary benefit and discounts'}, xlabel='30 Online shopping gives monetary benefit and discounts', ylabel='count'>

# %%
n=30
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'31 Enjoyment is derived from shopping online'}, xlabel='31 Enjoyment is derived from shopping online', ylabel='count'>

# %%
n=31
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'32 Shopping online is convenient and flexible'}, xlabel='32 Shopping online is convenient and flexible', ylabel='count'>

# %%
n=32
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'33 Return and replacement policy of the e-tailer is important for purchase decision'}, xlabel='33 Return and replacement policy of the e-tailer is important for purchase decision', ylabel='count'>

# %%
n=33
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'34 Gaining access to loyalty programs is a benefit of shopping online'}, xlabel='34 Gaining access to loyalty programs is a benefit of shopping online', ylabel='count'>

# %%
n=34
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'35 Displaying quality Information on the website improves satisfaction of customers'}, xlabel='35 Displaying quality Information on the website improves satisfaction of customers', ylabel='count'>

# %%
n=35
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'36 User derive satisfaction while shopping on a good quality website or application'}, xlabel='36 User derive satisfaction while shopping on a good quality website or application', ylabel='count'>

# %%
n=36
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'37 Net Benefit derived from shopping online can lead to users satisfaction'}, xlabel='37 Net Benefit derived from shopping online can lead to users satisfaction', ylabel='count'>

# %%
n=37
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'38 User satisfaction cannot exist without trust'}, xlabel='38 User satisfaction cannot exist without trust', ylabel='count'>

# %%
n=38
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'39 Offering a wide variety of listed product in several category'}, xlabel='39 Offering a wide variety of listed product in several category', ylabel='count'>

# %%
n=39
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'40 Provision of complete and relevant product information'}, xlabel='40 Provision of complete and relevant product information', ylabel='count'>

# %%
n=40
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'41 Monetary savings'}, xlabel='41 Monetary savings', ylabel='count'>

# %%
n=41
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'42 The Convenience of patronizing the online retailer'}, xlabel='42 The Convenience of patronizing the online retailer', ylabel='count'>

# %%
n=42
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'43 Shopping on the website gives you the sense of adventure'}, xlabel='43 Shopping on the website gives you the sense of adventure', ylabel='count'>

# %%
n=43
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'44 Shopping on your preferred e-tailer enhances your social status'}, xlabel='44 Shopping on your preferred e-tailer enhances your social status', ylabel='count'>

# %%
n=44
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'45 You feel gratification shopping on your favorite e-tailer'}, xlabel='45 You feel gratification shopping on your favorite e-tailer', ylabel='count'>

# %%
n=45
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'46 Shopping on the website helps you fulfill certain roles'}, xlabel='46 Shopping on the website helps you fulfill certain roles', ylabel='count'>

# %%
n=46
plt.figure(figsize=(15,7))
plt.title(df.columns[n],fontsize=20,color='Blue')
sns.countplot(df[df.columns[n]])
# Out:
# <AxesSubplot:title={'center':'47 Getting value for money spent'}, xlabel='47 Getting value for money spent', ylabel='count'>

# %% [markdown]
# most of the customers agree that getting value for money spent.Some customer strongly agree with this and few customer not agree with this.
